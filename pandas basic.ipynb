# %%
print ("I want to become a data scientist")
# Out:
# I want to become a data scientist

# %%
print ("Yes I can because god and my family is always with me")
# Out:
# Yes I can because god and my family is always with me

# %%
# Now I am gonna to learn the basic of 'Pandas'

# %%
import pandas as pd #pd = alis or nick nick name

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("services.csv")

# %%
df.head()
# Out:
#   Emp ID      Last   First       Full Name                        Email  \
# 0  E1180    Bacata  Stevie    StevieBacata    stevie.bacata@pushpin.com
# 1  E1110     BARRY    Adam       AdamBARRY       adam.barry@pushpin.com
# 2  E1232     Betts  Connor     ConnorBetts     connor.betts@pushpin.com
# 3  E1243  martinez  carlos  carlosmartinez  carlos.martinez@pushpin.com
# 4  E1248      Biti  Yvette      YvetteBiti      yvette.biti@pushpin.com
#
#   Date of Hire Last Review  Next Review        Department      Location  \
# 0   18-04-2008  01-07-2016          NaN             Sales  02-West 2635
# 1   27-04-2004  31-03-2017          NaN  Customer Service  02-West 2018
# 2   18-11-2014  13-10-2016          NaN             Sales  02-West 2347
# 3   18-08-2015  10-03-2017          NaN   Human Resources  03-West 2764
# 4   20-01-2016  15-07-2016          NaN             Sales  02-West 2589
#
#    Floor  Unnamed: 11  Unnamed: 12
# 0      2          NaN          NaN
# 1      2          NaN          NaN
# 2      2          NaN          NaN
# 3      3          NaN          NaN
# 4      2          NaN          NaN

# %%
df.head(3)
# Out:
#   Emp ID    Last   First     Full Name                      Email  \
# 0  E1180  Bacata  Stevie  StevieBacata  stevie.bacata@pushpin.com
# 1  E1110   BARRY    Adam     AdamBARRY     adam.barry@pushpin.com
# 2  E1232   Betts  Connor   ConnorBetts   connor.betts@pushpin.com
#
#   Date of Hire Last Review  Next Review        Department      Location  \
# 0   18-04-2008  01-07-2016          NaN             Sales  02-West 2635
# 1   27-04-2004  31-03-2017          NaN  Customer Service  02-West 2018
# 2   18-11-2014  13-10-2016          NaN             Sales  02-West 2347
#
#    Floor  Unnamed: 11  Unnamed: 12
# 0      2          NaN          NaN
# 1      2          NaN          NaN
# 2      2          NaN          NaN

# %%
df.tail()
# Out:
#    Emp ID           Last    First             Full Name  \
# 30  E1245         Senome   Radhya          RadhyaSenome
# 31  E1207  Son van  Burg  Natasha  NatashaSon van  Burg
# 32  E1244        Staples    Peter          PeterStaples
# 33  E1252           WANG      Mei               MeiWANG
# 34  E1237          Zhang    Aanya            AanyaZhang
#
#                                 Email Date of Hire Last Review  Next Review  \
# 30          radhya.senome@pushpin.com   17-11-2015  08-08-2016          NaN
# 31  natasha.son van  burg@pushpin.com   20-06-2011  17-05-2016          NaN
# 32          peter.staples@pushpin.com   18-11-2015  07-03-2017          NaN
# 33               mei.wang@pushpin.com   11-01-2010  14-04-2017          NaN
# 34            aanya.zhang@pushpin.com   05-01-2015  09-10-2016          NaN
#
#    Department       Location  Floor  Unnamed: 11  Unnamed: 12
# 30      Sales  02-North 2260      2          NaN          NaN
# 31      Sales   02-West 2578      2          NaN          NaN
# 32      Sales  02-North 2654      2          NaN          NaN
# 33  Executive   01-West 2783      1          NaN          NaN
# 34      Sales  02-North 2793      2          NaN          NaN

# %%
df.tail(3)
# Out:
#    Emp ID     Last  First     Full Name                      Email  \
# 32  E1244  Staples  Peter  PeterStaples  peter.staples@pushpin.com
# 33  E1252     WANG    Mei       MeiWANG       mei.wang@pushpin.com
# 34  E1237    Zhang  Aanya    AanyaZhang    aanya.zhang@pushpin.com
#
#    Date of Hire Last Review  Next Review Department       Location  Floor  \
# 32   18-11-2015  07-03-2017          NaN      Sales  02-North 2654      2
# 33   11-01-2010  14-04-2017          NaN  Executive   01-West 2783      1
# 34   05-01-2015  09-10-2016          NaN      Sales  02-North 2793      2
#
#     Unnamed: 11  Unnamed: 12
# 32          NaN          NaN
# 33          NaN          NaN
# 34          NaN          NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Emp ID', 'Last', 'First', 'Full Name', 'Email', 'Date of Hire',
#        'Last Review', 'Next Review', 'Department', 'Location', 'Floor',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Emp ID',
#  'Last',
#  'First',
#  'Full Name',
#  'Email',
#  'Date of Hire',
#  'Last Review',
#  'Next Review',
#  'Department',
#  'Location',
#  'Floor',
#  'Unnamed: 11',
#  'Unnamed: 12']

# %%
df['Emp ID']
# Out:
# 0     E1180
# 1     E1110
# 2     E1232
# 3     E1243
# 4     E1248
# 5     E1227
# 6     E1230
# 7     E1162
# 8     E1001
# 9     E1224
# 10    E1203
# 11    E1211
# 12    E1198
# 13    E1003
# 14    E1253
# 15    E1235
# 16    E1221
# 17    E1186
# 18    E1218
# 19    E1215
# 20    E1241
# 21    E1246
# 22    E1172
# 23    E1134
# 24    E1150
# 25    E1004
# 26    E1239
# 27    E1250
# 28    E1192
# 29    E1249
# 30    E1245
# 31    E1207
# 32    E1244
# 33    E1252
# 34    E1237
# Name: Emp ID, dtype: object

# %%
df['Email']
# Out:
# 0             stevie.bacata@pushpin.com
# 1                adam.barry@pushpin.com
# 2              connor.betts@pushpin.com
# 3           carlos.martinez@pushpin.com
# 4               yvette.biti@pushpin.com
# 5                jim.boller@pushpin.com
# 6               charlie.bui@pushpin.com
# 7           barbara.carlton@pushpin.com
# 8                 joe.carol@pushpin.com
# 9               jim.chaffee@pushpin.com
# 10          samantha.chairs@pushpin.com
# 11              uma.chaudri@pushpin.com
# 12            elizabeth.chu@pushpin.com
# 13               eric.chung@pushpin.com
# 14          elizabeth.clark@pushpin.com
# 15               anna.clark@pushpin.com
# 16             sabrina.cole@pushpin.com
# 17          janet.comuntzis@pushpin.com
# 18              bob.decker@pushpin.com
# 19            tina.de siato@pushpin.com
# 20        alexandra.donnell@pushpin.com
# 21               mark.ellis@pushpin.com
# 22       nicholas.fernandes@pushpin.com
# 23              mary.ferris@pushpin.com
# 24             susan.filosa@pushpin.com
# 25          daniel.flanders@pushpin.com
# 26         leighton.forrest@pushpin.com
# 27              phoebe.gour@pushpin.com
# 28              mihael.khan@pushpin.com
# 29             sean.sanders@pushpin.com
# 30            radhya.senome@pushpin.com
# 31    natasha.son van  burg@pushpin.com
# 32            peter.staples@pushpin.com
# 33                 mei.wang@pushpin.com
# 34              aanya.zhang@pushpin.com
# Name: Email, dtype: object

# %%
df['Full Name']
# Out:
# 0             StevieBacata
# 1                AdamBARRY
# 2              ConnorBetts
# 3           carlosmartinez
# 4               YvetteBiti
# 5                JimBOLLER
# 6               CharlieBui
# 7           BarbaraCarlton
# 8                 JoeCAROL
# 9               JimCHAFFEE
# 10          SamanthaChairs
# 11              UmaCHAUDRI
# 12            ElizabethCHU
# 13               EricCHUNG
# 14          elizabethCLARK
# 15               ANNACLARK
# 16             SabrinaCOLE
# 17          JanetCOMUNTZIS
# 18              BobDECKER
# 19            TinaDE SIATO
# 20        AlexandraDONNELL
# 21               MarkELLIS
# 22       NicholasFernandes
# 23              MaryFERRIS
# 24             SusanFILOSA
# 25          DanielFLANDERS
# 26         LeightonForrest
# 27              PhoebeGour
# 28              MihaelKhan
# 29             SeanSANDERS
# 30            RadhyaSenome
# 31    NatashaSon van  Burg
# 32            PeterStaples
# 33                 MeiWANG
# 34              AanyaZhang
# Name: Full Name, dtype: object

# %%
type(df['Full Name'])
# Out:
# pandas.core.series.Series

# %%
list(df['Full Name'])
# Out:
# ['StevieBacata',
#  'AdamBARRY',
#  'ConnorBetts',
#  'carlosmartinez',
#  'YvetteBiti',
#  'JimBOLLER',
#  'CharlieBui',
#  'BarbaraCarlton',
#  'JoeCAROL',
#  'JimCHAFFEE',
#  'SamanthaChairs',
#  'UmaCHAUDRI',
#  'ElizabethCHU',
#  'EricCHUNG',
#  'elizabethCLARK',
#  'ANNACLARK',
#  'SabrinaCOLE',
#  'JanetCOMUNTZIS',
#  'BobDECKER\x01',
#  'TinaDE SIATO',
#  'AlexandraDONNELL',
#  'MarkELLIS',
#  'NicholasFernandes',
#  'MaryFERRIS',
#  'SusanFILOSA',
#  'DanielFLANDERS',
#  'LeightonForrest',
#  'PhoebeGour',
#  'MihaelKhan',
#  'SeanSANDERS',
#  'RadhyaSenome',
#  'NatashaSon van  Burg',
#  'PeterStaples',
#  'MeiWANG',
#  'AanyaZhang']

# %%
df[['Full Name']]
# Out:
#                Full Name
# 0           StevieBacata
# 1              AdamBARRY
# 2            ConnorBetts
# 3         carlosmartinez
# 4             YvetteBiti
# 5              JimBOLLER
# 6             CharlieBui
# 7         BarbaraCarlton
# 8               JoeCAROL
# 9             JimCHAFFEE
# 10        SamanthaChairs
# 11            UmaCHAUDRI
# 12          ElizabethCHU
# 13             EricCHUNG
# 14        elizabethCLARK
# 15             ANNACLARK
# 16           SabrinaCOLE
# 17        JanetCOMUNTZIS
# 18            BobDECKER
# 19          TinaDE SIATO
# 20      AlexandraDONNELL
# 21             MarkELLIS
# 22     NicholasFernandes
# 23            MaryFERRIS
# 24           SusanFILOSA
# 25        DanielFLANDERS
# 26       LeightonForrest
# 27            PhoebeGour
# 28            MihaelKhan
# 29           SeanSANDERS
# 30          RadhyaSenome
# 31  NatashaSon van  Burg
# 32          PeterStaples
# 33               MeiWANG
# 34            AanyaZhang

# %%
type(df[['Full Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Emp ID', 'Last', 'First', 'Full Name', 'Email', 'Date of Hire',
#        'Last Review', 'Next Review', 'Department', 'Location', 'Floor',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df[['Emp ID', 'Full Name', 'Next Review']]
# Out:
#    Emp ID             Full Name  Next Review
# 0   E1180          StevieBacata          NaN
# 1   E1110             AdamBARRY          NaN
# 2   E1232           ConnorBetts          NaN
# 3   E1243        carlosmartinez          NaN
# 4   E1248            YvetteBiti          NaN
# 5   E1227             JimBOLLER          NaN
# 6   E1230            CharlieBui          NaN
# 7   E1162        BarbaraCarlton          NaN
# 8   E1001              JoeCAROL          NaN
# 9   E1224            JimCHAFFEE          NaN
# 10  E1203        SamanthaChairs          NaN
# 11  E1211            UmaCHAUDRI          NaN
# 12  E1198          ElizabethCHU          NaN
# 13  E1003             EricCHUNG          NaN
# 14  E1253        elizabethCLARK          NaN
# 15  E1235             ANNACLARK          NaN
# 16  E1221           SabrinaCOLE          NaN
# 17  E1186        JanetCOMUNTZIS          NaN
# 18  E1218            BobDECKER          NaN
# 19  E1215          TinaDE SIATO          NaN
# 20  E1241      AlexandraDONNELL          NaN
# 21  E1246             MarkELLIS          NaN
# 22  E1172     NicholasFernandes          NaN
# 23  E1134            MaryFERRIS          NaN
# 24  E1150           SusanFILOSA          NaN
# 25  E1004        DanielFLANDERS          NaN
# 26  E1239       LeightonForrest          NaN
# 27  E1250            PhoebeGour          NaN
# 28  E1192            MihaelKhan          NaN
# 29  E1249           SeanSANDERS          NaN
# 30  E1245          RadhyaSenome          NaN
# 31  E1207  NatashaSon van  Burg          NaN
# 32  E1244          PeterStaples          NaN
# 33  E1252               MeiWANG          NaN
# 34  E1237            AanyaZhang          NaN

# %%
df.dtypes
# Out:
# Emp ID           object
# Last             object
# First            object
# Full Name        object
# Email            object
# Date of Hire     object
# Last Review      object
# Next Review     float64
# Department       object
# Location         object
# Floor             int64
# Unnamed: 11     float64
# Unnamed: 12     float64
# dtype: object

# %%
pd.read_excel("services1.xlsx")
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# 15  E1235          CLARK       ANNA             ANNACLARK
# 16  E1221           COLE    Sabrina           SabrinaCOLE
# 17  E1186      COMUNTZIS      Janet        JanetCOMUNTZIS
# 18  E1218  DECKER_x0001_        Bob      BobDECKER_x0001_
# 19  E1215       DE SIATO       Tina          TinaDE SIATO
# 20  E1241        DONNELL  Alexandra      AlexandraDONNELL
# 21  E1246          ELLIS       Mark             MarkELLIS
# 22  E1172      Fernandes   Nicholas     NicholasFernandes
# 23  E1134         FERRIS       Mary            MaryFERRIS
# 24  E1150         FILOSA      Susan           SusanFILOSA
# 25  E1004       FLANDERS     Daniel        DanielFLANDERS
# 26  E1239        Forrest   Leighton       LeightonForrest
# 27  E1250           Gour     Phoebe            PhoebeGour
# 28  E1192           Khan     Mihael            MihaelKhan
# 29  E1249        SANDERS       Sean           SeanSANDERS
# 30  E1245         Senome     Radhya          RadhyaSenome
# 31  E1207  Son van  Burg    Natasha  NatashaSon van  Burg
# 32  E1244        Staples      Peter          PeterStaples
# 33  E1252           WANG        Mei               MeiWANG
# 34  E1237          Zhang      Aanya            AanyaZhang
#
#                                 Email Date of Hire Last Review  \
# 0           stevie.bacata@pushpin.com   2008-04-18  2016-07-01
# 1              adam.barry@pushpin.com   2004-04-27  2017-03-31
# 2            connor.betts@pushpin.com   2014-11-18  2016-10-13
# 3         carlos.martinez@pushpin.com   2015-08-18  2017-03-10
# 4             yvette.biti@pushpin.com   2016-01-20  2016-07-15
# 5              jim.boller@pushpin.com   2014-09-16  2016-06-30
# 6             charlie.bui@pushpin.com   2014-09-26  2016-09-06
# 7         barbara.carlton@pushpin.com   2006-03-27  2017-01-26
# 8               joe.carol@pushpin.com   2001-02-06  2016-08-14
# 9             jim.chaffee@pushpin.com   2014-06-02  2016-06-23
# 10        samantha.chairs@pushpin.com   2011-02-21  2016-09-16
# 11            uma.chaudri@pushpin.com   2012-03-26  2017-04-23
# 12          elizabeth.chu@pushpin.com   2010-02-16  2017-05-05
# 13             eric.chung@pushpin.com   2001-03-05  2016-06-19
# 14        elizabeth.clark@pushpin.com   2017-06-26  2017-04-03
# 15             anna.clark@pushpin.com   2014-12-22  2016-12-27
# 16           sabrina.cole@pushpin.com   2013-05-13  2016-12-16
# 17        janet.comuntzis@pushpin.com   2008-09-01  2016-08-16
# 18      bob.decker_x0001_@pushpin.com   2012-11-01  2016-07-15
# 19          tina.de siato@pushpin.com   2012-09-24  2017-04-10
# 20      alexandra.donnell@pushpin.com   2015-08-17  2016-10-15
# 21             mark.ellis@pushpin.com   2016-01-07  2016-09-01
# 22     nicholas.fernandes@pushpin.com   2006-11-07  2017-03-23
# 23            mary.ferris@pushpin.com   2005-07-20  2017-04-20
# 24           susan.filosa@pushpin.com   2006-02-01  2017-02-10
# 25        daniel.flanders@pushpin.com   2002-09-16  2016-08-04
# 26       leighton.forrest@pushpin.com   2015-05-01  2016-12-06
# 27            phoebe.gour@pushpin.com   2016-12-22  2016-06-18
# 28            mihael.khan@pushpin.com   2009-12-15  2016-07-12
# 29           sean.sanders@pushpin.com   2017-06-06  2016-12-27
# 30          radhya.senome@pushpin.com   2015-11-17  2016-08-08
# 31  natasha.son van  burg@pushpin.com   2011-06-20  2016-05-17
# 32          peter.staples@pushpin.com   2015-11-18  2017-03-07
# 33               mei.wang@pushpin.com   2010-01-11  2017-04-14
# 34            aanya.zhang@pushpin.com   2015-01-05  2016-10-09
#
#           Department       Location  Floor
# 0              Sales   02-West 2635      2
# 1   Customer Service   02-West 2018      2
# 2              Sales   02-West 2347      2
# 3    Human Resources   03-West 2764      3
# 4              Sales   02-West 2589      2
# 5         Accounting  03-North 2318      3
# 6              Sales  02-North 2694      2
# 7              Sales   02-West 2699      2
# 8          Executive  01-North 2321      1
# 9         Facilities   03-West 2432      3
# 10             Sales   02-West 2962      2
# 11   Human Resources  03-North 2134      3
# 12                IT   01-West 2425      1
# 13                IT   03-West 2796      3
# 14  Customer Service   02-West 2414      2
# 15        Accounting   03-West 2601      3
# 16  Customer Service   02-West 2537      2
# 17  Customer Service   02-West 2286      2
# 18                IT  01-North 2086      1
# 19                IT  01-North 2358      1
# 20        Accounting   03-West 2082      3
# 21                IT   03-West 2482      3
# 22        Accounting  02-North 2372      2
# 23             Sales  03-North 2392      3
# 24  Customer Service   02-West 2279      2
# 25             Sales  02-North 2639      2
# 26             Sales  02-North 2284      2
# 27             Sales  02-North 2910      2
# 28             Sales  02-North 2294      2
# 29   Human Resources   03-West 2765      3
# 30             Sales  02-North 2260      2
# 31             Sales   02-West 2578      2
# 32             Sales  02-North 2654      2
# 33         Executive   01-West 2783      1
# 34             Sales  02-North 2793      2

# %%
df1 = pd.read_excel("services1.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Emp ID                  object
# Last                    object
# First                   object
# Full Name               object
# Email                   object
# Date of Hire    datetime64[ns]
# Last Review     datetime64[ns]
# Department              object
# Location                object
# Floor                    int64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Emp ID', 'Last', 'First', 'Full Name', 'Email', 'Date of Hire',
#        'Last Review', 'Department', 'Location', 'Floor'],
#       dtype='object')

# %%
list(df1.columns)
# Out:
# ['Emp ID',
#  'Last',
#  'First',
#  'Full Name',
#  'Email',
#  'Date of Hire',
#  'Last Review',
#  'Department',
#  'Location',
#  'Floor']

# %%
df1[['Department', 'Location']]
# Out:
#           Department       Location
# 0              Sales   02-West 2635
# 1   Customer Service   02-West 2018
# 2              Sales   02-West 2347
# 3    Human Resources   03-West 2764
# 4              Sales   02-West 2589
# 5         Accounting  03-North 2318
# 6              Sales  02-North 2694
# 7              Sales   02-West 2699
# 8          Executive  01-North 2321
# 9         Facilities   03-West 2432
# 10             Sales   02-West 2962
# 11   Human Resources  03-North 2134
# 12                IT   01-West 2425
# 13                IT   03-West 2796
# 14  Customer Service   02-West 2414
# 15        Accounting   03-West 2601
# 16  Customer Service   02-West 2537
# 17  Customer Service   02-West 2286
# 18                IT  01-North 2086
# 19                IT  01-North 2358
# 20        Accounting   03-West 2082
# 21                IT   03-West 2482
# 22        Accounting  02-North 2372
# 23             Sales  03-North 2392
# 24  Customer Service   02-West 2279
# 25             Sales  02-North 2639
# 26             Sales  02-North 2284
# 27             Sales  02-North 2910
# 28             Sales  02-North 2294
# 29   Human Resources   03-West 2765
# 30             Sales  02-North 2260
# 31             Sales   02-West 2578
# 32             Sales  02-North 2654
# 33         Executive   01-West 2783
# 34             Sales  02-North 2793

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(df2.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
len((df2.columns))
# Out:
# 12

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/html.py:939, in _parser_dispatch(flavor)
#     937 else:
#     938     if not _HAS_LXML:
# --> 939         raise ImportError("lxml not found, please install it")
#     940 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 45.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lxml
# Successfully installed lxml-5.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 = url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.head(10)
# Out:
#   Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0  1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1  2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2  3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3  4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4  5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# 5  5   Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21
# 6  5   Arron Afflalo  SG  29  POR  25  19   752   94  227  ...  .851    6
# 7  6   Alexis Ajinça   C  26  NOP  68   8   957  181  329  ...  .818  104
# 8  7  Furkan Aldemir  PF  23  PHI  41   9   540   40   78  ...  .481   78
# 9  8    Cole Aldrich   C  26  NYK  61  16   976  144  301  ...  .781  101
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  222  301   68  27  22   60  147   398
# 1   19   28   16  16   7   14   24    94
# 2  324  523   66  38  86   99  222   537
# 3   54   77   15   4   9    9   30    60
# 4  220  247  129  41   7  116  167  1035
# 5  159  180  101  32   5   83  108   771
# 6   61   67   28   9   2   33   59   264
# 7  211  315   47  21  51   69  151   443
# 8   98  176   28  17  16   17   96    93
# 9  237  338   75  37  65   59  122   338
#
# [10 rows x 30 columns]

# %%
df3.tail(20)
# Out:
#       Rk           Player Pos Age   Tm   G  GS    MP   FG  FGA  ...    FT%  \
# 655  482  Shawne Williams  SF  28  TOT  63  22  1087  121  300  ...   .875
# 656  482  Shawne Williams  SF  28  MIA  44  22   924  102  240  ...   .848
# 657  482  Shawne Williams  SF  28  DET  19   0   163   19   60  ...  1.000
# 658  483      Jeff Withey   C  24  NOP  37   0   259   32   64  ...   .680
# 659  484     Nate Wolters  PG  23  TOT  21   0   247   20   57  ...   .333
# 660  484     Nate Wolters  PG  23  MIL  11   0   142   12   31  ...   .250
# 661  484     Nate Wolters  PG  23  NOP  10   0   105    8   26  ...   .500
# 662  485   Brandan Wright  PF  27  TOT  75   7  1449  233  363  ...   .696
# 663  485   Brandan Wright  PF  27  DAL  27   0   505  101  135  ...   .750
# 664  485   Brandan Wright  PF  27  BOS   8   0    86   12   21  ...   .500
# 665  485   Brandan Wright  PF  27  PHO  40   7   858  120  207  ...   .667
# 666  486    Dorell Wright  SF  29  POR  48   2   592   72  190  ...   .810
# 667  487      Tony Wroten  PG  21  PHI  30  15   895  175  434  ...   .667
# 668  488      James Young  SG  19  BOS  31   0   332   36  102  ...   .552
# 669  489       Nick Young  SG  29  LAL  42   0  1000  174  476  ...   .892
# 670  490   Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...   .655
# 671  490   Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...   .682
# 672  490   Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...   .606
# 673  491      Cody Zeller   C  22  CHO  62  45  1487  172  373  ...   .774
# 674  492     Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...   .823
#
#      ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 655   36  130  166   44   25  21   30  135   341
# 656   27  112  139   36   21  17   23  116   292
# 657    9   18   27    8    4   4    7   19    49
# 658   23   41   64   11    4  18   12   26    98
# 659    8   26   34   21    8   2   13   18    42
# 660    2   14   16   10    5   0    3   11    25
# 661    6   12   18   11    3   2   10    7    17
# 662  128  193  321   41   50  94   34  102   544
# 663   51   59  110   10   17  42   13   44   238
# 664    7   10   17    8    1   5    5    4    26
# 665   70  124  194   23   32  47   16   54   280
# 666   14   97  111   41   20  11   18   55   219
# 667   22   64   86  157   48   8  113   72   507
# 668    9   33   42   13    8   2    5   22   105
# 669   17   79   96   41   23  11   44   83   563
# 670  127  284  411  173  124  25  117  171  1071
# 671   75  170  245  135   86  17   75  115   685
# 672   52  114  166   38   38   8   42   56   386
# 673   97  265  362  100   34  49   62  156   472
# 674  146  319  465  113   18  52   76  205   833
#
# [20 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
list(df3.columns)
# Out:
# ['Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3[['Rk', 'Player', 'Pos']]
# Out:
#       Rk          Player Pos
# 0      1      Quincy Acy  PF
# 1      2    Jordan Adams  SG
# 2      3    Steven Adams   C
# 3      4     Jeff Adrien  PF
# 4      5   Arron Afflalo  SG
# ..   ...             ...  ..
# 670  490  Thaddeus Young  PF
# 671  490  Thaddeus Young  PF
# 672  490  Thaddeus Young  PF
# 673  491     Cody Zeller   C
# 674  492    Tyler Zeller   C
#
# [675 rows x 3 columns]

# %%
df3.to_csv("players_data.csv", index = False)
